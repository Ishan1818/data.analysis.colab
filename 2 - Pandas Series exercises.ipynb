# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan1818/data.analysis.colab/blob/main/2%20-%20Pandas%20Series%20exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas Series exercises

# %%
import numpy as np
import numpy as np

import pandas as pd
import pandas as pd

print(pd.__version__)
print(pd.__version__)
# Out:
# 2.2.2
# 2.2.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series creation

# %% [markdown]
# ### Create an empty pandas Series

# %%
a = pd.Series()

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X python list convert it to an Y pandas Series

# %%
x = [1,2,3,4,5]
Y = pd.Series(x)
Y
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
X = ['A','B','C']
print(X, type(X))

Y = pd.Series(X)
print(Y, type(Y)) # different type

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, name it 'My letters'

# %%
X = pd.Series([1,2,3,4])
X.name = 'My letters'
X
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: My letters, dtype: int64

# %%
X = pd.Series(['A','B','C'])

X.name = 'My letters'
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its values

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X.values
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
X = pd.Series(['A','B','C'])

X.values
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series indexation

# %% [markdown]
# ### Assign index names to the given X pandas Series

# %%
X = pd.Series([1,2,3,4])
indexx = ['A', 'B', 'C', 'D']
X.index = indexx
X
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
X = pd.Series(['A','B','C'])
index_names = ['first', 'second', 'third']

X.index = index_names
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its first element

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X[0]
# Out:
# 'a'

# %%
X = pd.Series(['A','B','C'], index=['first', 'second', 'third'])

#X[0] # by position
#X.iloc[0] # by position
X['first'] # by index

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its last element

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X.iloc[-1]
# Out:
# 'd'

# %%
X = pd.Series(['A','B','C'], index=['first', 'second', 'third'])

#X[-1] # by position
#X.iloc[-1] # by position
X['third'] # by index

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show all middle elements

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X[1:3]
Y = np.array([1,2,3,4])
Y[1:3]
# Out:
# array([2, 3])

# %%
X = pd.Series(['A','B','C','D','E'],
              index=['first','second','third','forth','fifth'])

#X[['second', 'third', 'forth']]
#X.iloc[1:-1] # by position
X[1:-1] # by position
# Out:
# second    B
# third     C
# forth     D
# dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the elements in reverse position

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X[::-1]
# Out:
# 3    d
# 2    c
# 1    b
# 0    a
# dtype: object

# %%
X = pd.Series(['A','B','C','D','E'],
              index=['first','second','third','forth','fifth'])

#X.iloc[::-1]
X[::-1]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the first and last elements

# %%
X = pd.Series(['a', 'b', 'c', 'd']) ###[[]] DOUBLE SQUARE BRACKETS BTW VERY NECESSARY
X.iloc[[0, -1]]
# Out:
# 0    a
# 3    d
# dtype: object

# %%
X = pd.Series(['A','B','C','D','E'],
              index=['first','second','third','forth','fifth'])

#X[['first', 'fifth']]
#X.iloc[[0, -1]]
X[[0, -1]]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series manipulation

# %% [markdown]
# ### Convert the given integer pandas Series to float

# %%
X = pd.Series(['1', '2', '3', '4'], dtype = int)
y = pd.Series(X, dtype = float)
y
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %%
X = pd.Series([1,2,3,4,5],
              index=['first','second','third','forth','fifth'])

pd.Series(X, dtype=np.float)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Reverse the given pandas Series (first element becomes last)

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X.iloc[::-1]
# Out:
# 3    d
# 2    c
# 1    b
# 0    a
# dtype: object

# %%
X = pd.Series([1,2,3,4,5],
              index=['first','second','third','forth','fifth'])

X[::-1]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Order (sort) the given pandas Series

# %%
X = pd.Series(['4', '2', '3', '1'])  ###VERY IMPORTANT sort_values()
X = X.sort_values()
X
# Out:
# 3    1
# 1    2
# 2    3
# 0    4
# dtype: object

# %%
X = pd.Series([4,2,5,1,3],
              index=['forth','second','fifth','first','third'])

X = X.sort_values()
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, set the fifth element equal to 10

# %%
X = pd.Series(['a', 'b', 'c', 'd', 'e', 'f'])
X[4] = '10'
X
# Out:
# 0     a
# 1     b
# 2     c
# 3     d
# 4    10
# 5     f
# dtype: object

# %%
X = pd.Series([1,2,3,4,5],
              index=['A','B','C','D','E'])

X[4] = 10
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, change all the middle elements to 0

# %%
X = pd.Series(['a', 'b', 'c', 'd'])
X[1:-1] = '0'
X
# Out:
# 0    a
# 1    0
# 2    0
# 3    d
# dtype: object

# %%
X = pd.Series([1,2,3,4,5],
              index=['A','B','C','D','E'])

X[1:-1] = 0
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, add 5 to every element

# %%
X = pd.Series(['1', '2', '3', '4'],dtype = int)
X + 5
# Out:
# 0    6
# 1    7
# 2    8
# 3    9
# dtype: int64

# %%
X = pd.Series([1,2,3,4,5])

X + 5

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series boolean arrays (also called masks)

# %% [markdown]
# ### Given the X pandas Series, make a mask showing negative elements

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
mask = X < 0
mask
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# dtype: bool

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X <= 0
mask
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get the negative elements

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
X = X[X < 0]
X
# Out:
# 4   -4
# 5   -2
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X <= 0
X[mask]
# Out:
# 0   -1
# 2    0
# 3   -4
# 6    0
# 7    0
# 8   -9
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers higher than 5

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
mask = X > 5
X[mask]
# Out:
# 6    7
# 7    8
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X > 5
X[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers higher than the elements mean

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])

mask = X >= X.mean()
X[mask]
mask
X.mean()
# Out:
# np.float64(2.625)

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X > X.mean()
X[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers equal to 2 or 10

# %%
X = pd.Series([1,2,4,5,-4,-2,7,10,8])
mask = (X == 2) | (X == 10)
X[mask]
# Out:
# 1     2
# 7    10
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = (X == 2) | (X == 10)
X[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Logic functions

# %% [markdown]
# ### Given the X pandas Series, return True if none of its elements is zero

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
X.all()
# Out:
# np.True_

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

X.all()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, return True if any of its elements is zero

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
X.any()
# Out:
# np.True_

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

X.any()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Summary statistics

# %% [markdown]
# ### Given the X pandas Series, show the sum of its elements

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
X.sum()
# Out:
# np.int64(21)

# %%
X = pd.Series([3,5,6,7,2,3,4,9,4])

#np.sum(X)
X.sum()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the mean value of its elements

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
X.mean()
# Out:
# np.float64(2.625)

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])

#np.mean(X)
X.mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the max value of its elements

# %%
X = pd.Series([1,2,4,5,-4,-2,7,8])
X.max()
# Out:
# 8

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])

#np.max(X)
X.max()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
